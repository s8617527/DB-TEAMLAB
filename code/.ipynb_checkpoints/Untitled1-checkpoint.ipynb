# %%
from urllib import request
from bs4 import BeautifulSoup
from urllib.parse import urlparse
from urllib.request import urlopen
import re
import sqlite3
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import json
import requests
from fake_useragent import UserAgent
from lxml import html
import csv
import codecs

main = input("搜尋關鍵字")
momo1 = 'https://www.momoshop.com.tw/search/searchShop.jsp?keyword='
momourl = momo1 + main
pchome1 = 'https://ecshweb.pchome.com.tw/search/v3.3/?q='
pchomeurl = pchome1 + main
yahoo1 = 'https://tw.search.mall.yahoo.com/search/mall/product?p='
yahoourl = yahoo1 + main
shp1 = 'https://shopee.tw/search/?keyword='
shp2 = '&order=asc&page=0&sortBy=price'
shpurl = shp1 + main + shp2

print("momo: ", momourl)
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')
driver = webdriver.Chrome(options=chrome_options)
# Out:
# 搜尋關鍵字衛生紙
# momo:  https://www.momoshop.com.tw/search/searchShop.jsp?keyword=衛生紙

# %%
driver.get(momourl)
ps = driver.page_source

sp = BeautifulSoup(ps, "lxml")
root = 'https://www.momoshop.com.tw'
moitn = []
moitp = []
moiturl = []
try:
    name = sp.findAll("p", {'class':'prdName'})
    price = sp.findAll("span", {'class':'price'})
    t1 = sp.findAll("a", {'class':'goodsUrl'})
    for itnn in name:
        moitn.append(itnn.text)
    for itpp in price:
        moitp.append(itpp.text)
    for iturl in t1:
        t2 = root + iturl.get('href')
        moiturl.append(t2)
except:
    moitn.append("NULL")
    moitp.append("NULL")
    moiturl.append("NULL")
c = open("momo.csv","w", newline='', encoding='utf-8')      
writer = csv.writer(c, delimiter=',')       
writer.writerow(['item','price','url'])
for item in range(0, len(moitn)):
    temp = [moitn[item], moitp[item], moiturl[item]]
    writer.writerow(temp)   
c.close()
print(len(moitn), " ", len(moitp), " ", len(moiturl))
for item in range(0, len(moiturl)):
    print(moiturl[item])
# Out:
# 30   30   30
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6494870&Area=search&mdiv=403&oid=1_1&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=3252331&Area=search&mdiv=403&oid=1_2&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=7005423&Area=search&mdiv=403&oid=1_3&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6780072&Area=search&mdiv=403&oid=1_4&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6532205&Area=search&mdiv=403&oid=1_5&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6781146&Area=search&mdiv=403&oid=1_6&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6955871&Area=search&mdiv=403&oid=1_7&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6847838&Area=search&mdiv=403&oid=1_8&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=3613978&Area=search&mdiv=403&oid=1_9&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6168412&Area=search&mdiv=403&oid=1_10&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6958136&Area=search&mdiv=403&oid=1_11&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6958117&Area=search&mdiv=403&oid=1_12&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6972777&Area=search&mdiv=403&oid=1_13&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6662139&Area=search&mdiv=403&oid=1_14&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6972770&Area=search&mdiv=403&oid=1_15&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6549441&Area=search&mdiv=403&oid=1_16&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6847814&Area=search&mdiv=403&oid=1_17&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=4124738&Area=search&mdiv=403&oid=1_18&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=4722722&Area=search&mdiv=403&oid=1_19&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=3526154&Area=search&mdiv=403&oid=1_20&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=4804424&Area=search&mdiv=403&oid=1_21&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=7036318&Area=search&mdiv=403&oid=1_22&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=7005422&Area=search&mdiv=403&oid=1_23&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6961581&Area=search&mdiv=403&oid=1_24&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=4804429&Area=search&mdiv=403&oid=1_25&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=7252730&Area=search&mdiv=403&oid=1_26&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6773041&Area=search&mdiv=403&oid=1_27&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=4804431&Area=search&mdiv=403&oid=1_28&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6847879&Area=search&mdiv=403&oid=1_29&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99
# https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6847843&Area=search&mdiv=403&oid=1_30&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99

# %%
print("pchome: ", pchomeurl)
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.113 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest',
    'accept' : 'pplication/json, text/javascript, */*; q=0.01'
}
r = requests.get(pchomeurl,headers=headers,allow_redirects=True)
sp = BeautifulSoup(r.text, "lxml")
print(sp.findAll("div", class_ = 'Cm_C'))
pcitems = []
pcprices = []
pcurls = []
try:
    name = sp.find("div",{'class':'Cm_C'}).findAll("h5", {'class':'prod_name'})
    print(name)
    price = sp.find("div",{'class':'Cm_C'}).findAll("span", {'class':'value'})
    for itnn in name:
        pcitems.append(itnn.text)
    for itpp in price:
        pcprices.append(itpp.text)
    for iturl in name:
        t2 = iturl.get('href')
        pcurls.append(t2)
except:
    pcitems.append("NULL")
    pcprices.append("NULL")
    pcurls.append("NULL")
print(len(pcitems), " ", len(pcprices), " ", len(pcurls))      
for item in range(0, len(pcurls)):
    print(pcurls[item])
c = open("pchome.csv","w", newline='', encoding='utf-8')      
writer = csv.writer(c, delimiter=',')       
writer.writerow(['item','price','url'])
for item in range(0, len(moitn)):
    temp = [pcitems[item], pcprices[item], pcurls[item]]
    writer.writerow(temp)
c.close()
# Out:
# pchome:  https://ecshweb.pchome.com.tw/search/v3.3/?q=衛生紙
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-d9fae136838e> in <module>
#       4     'X-Requested-With': 'XMLHttpRequest',
#       5     'accept' : 'pplication/json, text/javascript, */*; q=0.01',
# ----> 6     'referer' : pchomeurl.decode(utf-8)
#       7 }
#       8 r = requests.get(pchomeurl,headers=headers,allow_redirects=True)
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
print("yahoo: ", yahoourl)
driver.get(yahoourl)
ps = driver.page_source
sp = BeautifulSoup(ps, "lxml")
yaitn = []
yaitp = []
yaiturl = []
try:
    name = sp.find("div",{'class':'main'}).findAll("span", class_ = re.compile('2HWui'))
    price = sp.findAll(class_ = re.compile('31jkj'))
    url = sp.findAll("a", class_ = re.compile('3LORP'))
    print(len(url))
    for itnn in name:
        yaitn.append(itnn.text)
    for itpp in price:
        yaitp.append(itpp.text)
    for iturl in url:
        t1 = iturl.get('href')
        yaiturl.append(t1)
except:
    yaitn.append("NULL")
    yaitp.append("NULL")
    yaiturl.append("NULL")
c = open("yahoo.csv","w", newline='', encoding='utf-8')      
writer = csv.writer(c, delimiter=',')       
writer.writerow(['item','price','url'])
for item in range(0, len(moitn)):
    temp = [yaitn[item], yaitp[item], yaiturl[item]]
    writer.writerow(temp)
c.close()
print(len(yaitn), " ", len(yaitp), " ", len(yaiturl))
for item in range(0, len(yaiturl)):
    print(yaiturl[item])

# %%
print("蝦皮: ", shpurl)
headers = {
    'User-Agent': 'Googlebot'
}
r = requests.get(shpurl,headers=headers,allow_redirects=True)
sp = BeautifulSoup(r.text, "lxml")
root = 'https://shopee.tw'
try:
    name = sp.find_all("div", class_="_1NoI8_ _16BAGk")
    p1 = sp.find_all("div", class_="_2lBkmX")
    links = sp.findAll("a", {'data-sqe':'link'})
    spitems = []
    spprices = []
    spurls = []
    for itnn in name:
        spitems.append(itnn.text)
        ##print(itnn.text)
    for itpp in p1:
        p2 = itpp.find(class_ = '_341bF0')
        spprices.append(p2.text)
    for iturl in links:
        t1 = root + iturl.get('href')
        spurls.append(t1)
except:
    spitems.append("NULL")
    spprices.append("NULL")
    spurls.append("NULL")
c = open("shopee.csv","w", newline='', encoding='utf-8')      
writer = csv.writer(c, delimiter=',')       
writer.writerow(['item','price','url'])
for item in range(0, len(moitn)):
    temp = [spitems[item], spprices[item], spurls[item]]
    writer.writerow(temp)
c.close()
for item in range(0, len(spitems)):
    print(spurls[item])
# Out:
# 蝦皮:  https://shopee.tw/search/?keyword=衛生紙&order=asc&page=0&sortBy=price
# https://shopee.tw/現貨-75-酒精濕紙巾-消毒-奈森克林隨身包濕紙巾酒精濕紙巾濕紙巾單片裝超大尺寸外出必備【YB0005】-i.4278725.4916331794
# https://shopee.tw/奈森克林ㄐㄧㄡˇ精濕紙巾60張濕紙巾衛生紙巾擦露營紙巾衛生紙媽媽包水濕巾衛生巾濕紙巾【YB0002】-i.4278725.3617015782
# https://shopee.tw/24H-日本生活-超爽快系列-勁涼-濕紙巾-30-抽-i.170798549.2908926121
# https://shopee.tw/-現貨-韓國面紙60抽-點心犬-塗鴉款-紙巾-便攜-出門必備-隨身包面紙【金興發】-i.16859089.1772581528
# https://shopee.tw/-台灣寄出-親自實拍-雙層防水無痕背膠-紙巾架-紙巾盒-衛生紙架-紙巾置物架-紙巾收納架-衛生紙盒-衛生紙櫃-紙巾櫃-i.149523494.2524449085
# https://shopee.tw/易可可-ecoco-當天出貨-面紙盒-衛生紙架-廚房紙巾盒-衛生紙置物盒-多功能衛生紙盒-衛生紙盒-面紙-無痕免釘牆-i.192715768.4905077793
# https://shopee.tw/台灣現貨📢快速出貨📢多功能防水收納面紙盒-廁所衛生紙收納-黏貼無痕面紙架-浴室創意收納-置物架-塑膠面紙盒-收納盒-i.139777760.2503745308
# https://shopee.tw/限時降價（艾多美衛生紙72包宅配）-（現貨麻吉家族衛生紙）環保衛生紙-衛生紙抽-蜂膠牙膏-牙刷-i.114544724.2122454460
# https://shopee.tw/「🌈🔥」加購價《全新正品現貨喔》KLEENEX-舒潔-面紙-衛生紙-迪士尼-米妮米奇-i.4891743.184860353
# https://shopee.tw/舒潔抽取式衛生紙-舒潔紙手帕-歐芮坦細柔抽取式超柔軟衛生紙-i.3296881.856957228
# https://shopee.tw/樂雅抽取式衛生紙(100抽x80包-箱)一包6元超商一單最高24包-另有-300抽小抽-衛生紙-大捲紙擦手紙廚房用紙極度-i.23670161.1211134420
# https://shopee.tw/新柔衛生紙一箱84包-i.19378848.2852252776
# https://shopee.tw/抽取式衛生紙-超商一單最高24包100抽-i.19378848.2488569098
